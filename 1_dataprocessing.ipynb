# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

# %%
f = open('/content/drive/MyDrive/Ex041113 (1).log', 'r')

# %%
g = open('output.csv', 'w', newline = '')
write = csv.writer(g)

# %%
for i in f:
  a = i.split()
  if a[0] == '#Fields:':      # Fields row
    fields = a[1:]
    write.writerow(fields)
  if a[0] == '2004-11-13':    # Data rows
    write.writerow(a)

# %%
f.close()
g.close()
